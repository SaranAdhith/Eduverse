# %% [markdown]
# # 02 — Primary analysis
#
# Per-participant, per-block **learning gain** (post − pre on the block's anchor items, plus per-topic posterior delta). Paired t-test if Shapiro–Wilk doesn't reject normality; Wilcoxon signed-rank otherwise. Report effect size (Cohen's d, paired) and 95% CI.

# %%
import os
import sys

sys.path.insert(0, os.path.abspath('..'))
from lib import plots

EXPORT_PATH = os.environ.get('EXPORT_PATH', '../fixtures/P001.tar.gz')
plots.apply_style()

# %% [markdown]
# ## Per-block learning gain
# personalized vs fixed, within-subject.

# %%
# gains_personalized, gains_fixed = ...  (fill from mastery_trajectory)
# metrics.cohens_d_paired(gains_fixed, gains_personalized)

# %% [markdown]
# ## Significance test
# ```python
# from scipy import stats
# w, p_norm = stats.shapiro(diffs)
# if p_norm > 0.05:
#     t, p = stats.ttest_rel(post, pre)
# else:
#     t, p = stats.wilcoxon(post, pre)
# ```

# %%
# Runs on the fixture with a degenerate (N=1) sample as a smoke test.
