# %% [markdown]
# # 04 — Qualitative
#
# Short coding of free-text end-of-study preference responses (personalized vs fixed). Populated post-pilot.

# %%
import os
import sys

sys.path.insert(0, os.path.abspath('..'))
from lib import plots

EXPORT_PATH = os.environ.get('EXPORT_PATH', '../fixtures/P001.tar.gz')
plots.apply_style()

# %%
# Coding frame + counts once free-text responses are collected.
